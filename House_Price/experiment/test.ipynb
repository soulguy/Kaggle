# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
train_data = pd.read_csv('../data/train.csv')
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
train_data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(train_data['SalePrice'])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
print("Skewness: %f" % train_data['SalePrice'].skew())
print("Kurtosis: %f" % train_data['SalePrice'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %%
plt.figure(figsize=(15,8))
sns.boxplot(train_data.YearBuilt, train_data.SalePrice)

# %%
train_sort = pd.read_excel('../data/sortdata.xls')
train_sort
# Out:
#                  variable  Data Type   Segment  Expectation      Comment
# 0                      id           1        2          1.0         房屋售价
# 1              MSSubClass           1        1          3.0        建筑的等级
# 2                MSZoning           2        2          3.0         区域分类
# 3             LotFrontage           1        2          2.0    距离街道的直线距离
# 4                 LotArea           1        1          3.0         地皮面积
# 5                  Street           2        2          2.0         街道类型
# 6                   Alley           2        2          2.0         巷子类型
# 7                LotShape           2        1          2.0       房子整体形状
# 8             LandContour           2        1          2.0        平整度级别
# 9               Utilities           2        2          3.0       公共设施类型
# 10              LotConfig           2        1          3.0         房屋配置
# 11              LandSlope           2        1          2.0          倾斜度
# ...

# %%
train_sort.loc[[4,12,17,19,38,39,41,46,61,74]]
# Out:
#                  variable  Data Type   Segment  Expectation   Comment
# 4                 LotArea           1        1          3.0      地皮面积
# 12           Neighborhood           2        2          2.0    市区物理位置
# 17            OverallQual           2        0          3.0    总体状况评价
# 19              YearBuilt           2        0          2.0      建筑年份
# 38            TotalBsmtSF           1        1          2.0    地下室总面积
# 39                Heating           2        2          2.0      供暖类型
# 41             CentralAir           2        2          2.0    中央空调状况
# 46              GrLivArea           1        1          3.0  地面以上居住面积
# 61  GarageCars&GarageArea           1        1          2.0      车库面积
# 74                MiscVal           1        2          2.0   其他杂项特征值

# %%
# 验证主要特征是否满足要求
# 1.类别型
# CentralAir
data = pd.concat([train_data['SalePrice'],train_data['CentralAir']],axis=1)
fig = sns.boxplot(x = 'CentralAir',y = 'SalePrice',data = data)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 1.5, 0, 800000)

# %%
# OverallQual
data = pd.concat([train_data['SalePrice'],train_data['OverallQual']],axis=1)
fig = sns.boxplot(x = 'OverallQual',y = 'SalePrice',data = data)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 9.5, 0, 800000)

# %%
# YearBuilt
data = pd.concat([train_data['SalePrice'],train_data['YearBuilt']],axis=1)
f, ax = plt.subplots(figsize=(26, 12))
fig = sns.boxplot(x='YearBuilt',y='SalePrice',data = data)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 111.5, 0, 800000)

# %%
# Neighborhood
data = pd.concat([train_data['SalePrice'],train_data['Neighborhood']],axis=1)
f1,ax=plt.subplots(figsize=(26,12))
fig = sns.boxplot(x='Neighborhood',y='SalePrice',data=data)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 24.5, 0, 800000)

# %%
# 2.数值型
# LotArea
data = pd.concat([train_data['SalePrice'],train_data['LotArea']],axis=1)
data.plot.scatter(x='LotArea',y='SalePrice',ylim=(0,800000))

# %%
# TotalBsmtSF
data = pd.concat([train_data['SalePrice'],train_data['TotalBsmtSF']],axis=1)
data.plot.scatter('TotalBsmtSF','SalePrice',ylim=(0,800000))

# %%
# GrLivArea
data = pd.concat([train_data['SalePrice'],train_data['GrLivArea']],axis=1)
data.plot.scatter('GrLivArea','SalePrice',ylim=(0,800000))

# %%
# GarageCars&GarageArea
var = ['GarageArea','GarageCars']
for index in range(2):
    data = pd.concat([train_data['SalePrice'],train_data[var[index]]],axis=1)
    data.plot.scatter(x=var[index],y='SalePrice',ylim=(0,800000))

# %%
# MiscVal
data = pd.concat([train_data['SalePrice'],train_data['MiscVal']],axis=1)
data.plot.scatter('MiscVal','SalePrice',ylim=(0,800000))

# %%
corrmat = train_data.corr()
f, ax = plt.subplots(figsize=(20, 9))
sns.heatmap(corrmat, vmax=0.8, square=True)

# %%
# 由上图可以发现 和 SalePrice相关的更高的feature事
# OverallQual YealBuilt  TotalBsmtSF 1stFlrSF GrLivArea FullBath TotRmsAbvGrd GarageCars GarageArea
# 但是这还只是我们肉眼看到的 还不够科学 还不够精确
# 但是上面有的feature是类似的 比如 GarageCars GarageArea 还有TotalBsmtSF 1stFlrSF 还要做取舍
# 而且上面的feature 还只是数值型的 像一些离散型的属性还没有比较 还进一步需要处理 
# Neiborhood
# 这里使用sklearn进行处理 
from sklearn import preprocessing
f_name = ['CentralAir','Neighborhood']
for x in f_name:
    label=preprocessing.LabelEncoder()
    train_data[x]=label.fit_transform(train_data[x])
corrmat = train_data.corr()
f,ax = plt.subplots(figsize=(20,9))
sns.heatmap(corrmat,vmax=0.8,square=True)

# %%
# 由上图可以看出‘CenterAir’和‘Neighborhood’的相关性不高 所以要去掉
# 房价关系矩阵
k  = 10 # 关系矩阵中将显示10个特征
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train_data[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, \
                 square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
# 从上面可以看出 数值接近1的相关程度越高
# GrLivArea OverallQual 相关性非常高
# FullBath 
# GarageCar和GarageArea 选择一个就行了 从相关程度可以看出 GarageCars更高
# 另外TotalBsmSF 和 1stFlrSF 我们选择TotalBsmSF
# 所以我们现在要考虑的属性如下
train_sort.loc[[17,19,38,46,49,54,61]]
# Out:
#                  variable  Data Type   Segment  Expectation      Comment
# 17            OverallQual           2        0          3.0       总体状况评价
# 19              YearBuilt           2        0          2.0         建筑年份
# 38            TotalBsmtSF           1        1          2.0       地下室总面积
# 46              GrLivArea           1        1          3.0     地面以上居住面积
# 49               FullBath           1        2          2.0        高档全浴室
# 54           TotRmsAbvGrd           1        1          2.0  地上除卧室以外的房间数
# 61  GarageCars&GarageArea           1        1          2.0         车库面积

# %%
sns.set()
x
sns.pairplot(train_data[cols],size=2.5)
plt.show()

# %% [markdown]
# # 模拟数据

# %%
from sklearn import preprocessing
from sklearn import linear_model,svm,gaussian_process
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import train_test_split
import numpy as np

# %%
# 获取数据
cols = ['OverallQual','GrLivArea','GarageCars','TotalBsmtSF','FullBath','TotRmsAbvGrd','YearBuilt']
x = train_data[cols].values
y = train_data['SalePrice'].values
x_scaled = preprocessing.StandardScaler().fit_transform(x)
y_scaled = preprocessing.StandardScaler().fit_transform(y.reshape(-1,1))
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y_scaled,test_size=0.33,random_state=42)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
clfs = {
        'svm':svm.SVR(),
        'RandomForestRegressor':RandomForestRegressor(n_estimators=400),
        'BayesianRidge':linear_model.BayesianRidge()
}
for clf in clfs:
    try:
        clfs[clf].fit(x_train,y_train)
        y_pred=clfs[clf].predict(x_test)
        print(clf+" cost: "+str(np.sum(y_pred-y_test)/len(y_pred))) # 这里是平均数
    except Exception as e:
        print(clf+"error")
        print(str(e))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# svm cost: -17.967306347608588
# RandomForestRegressor cost: -2.3135663984332804
# BayesianRidge cost: -17.191504692911582
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# 由于以上结果所以选择 RandomForestRegressor
cols = ['OverallQual','GrLivArea','GarageCars','TotalBsmtSF','FullBath','TotRmsAbvGrd','YearBuilt']
x = train_data[cols].values
y = train_data['SalePrice'].values
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.33,random_state=42)
clf = RandomForestRegressor(n_estimators=400)
clf.fit(X_train,Y_train)
clf.predict(X_test)
# Out:
# array([141915.        , 310911.1875    , 123884.875     , 169801.625     ,
#        307882.0125    ,  78067.375     , 192382.5       , 152981.        ,
#         78197.        , 114709.        , 160749.825     , 122424.25      ,
#         95242.75      , 221954.1625    , 188678.75      , 123773.54166667,
#        194976.        , 133634.4375    , 120027.375     , 197507.125     ,
#        163641.0475    , 218561.43416667, 170387.2425    , 125284.39583333,
#        186831.95      , 167164.1825    , 202240.9225    ,  97667.        ,
#        187732.25      , 205650.53      , 109954.875     , 235408.565     ,
#        180731.4675    , 110174.16666667, 257954.8975    , 142269.8125    ,
#        160219.41      , 206184.575     , 311964.6375    , 106351.875     ,
#        131842.375     , 232235.2325    , 118999.5875    , 369324.6775    ,
#        140742.4       , 160488.3075    , 126240.62797619, 115407.5875    ,
# ...

# %%
Y_test
# Out:
# array([154500, 325000, 115000, 159000, 315500,  75500, 311500, 146000,
#         84500, 135500, 145000, 130000,  81000, 214000, 181000, 134500,
#        183500, 135000, 118400, 226000, 155000, 210000, 173500, 129000,
#        192000, 153900, 181134, 141000, 181000, 208900, 127000, 284000,
#        200500, 135750, 255000, 140000, 138000, 219500, 310000,  97000,
#        114500, 205000, 119500, 253293, 128500, 117500, 115000, 127000,
#        451950, 144000, 119000, 196000, 115000, 287000, 144500, 260000,
#        213000, 175000, 107000, 107500,  68500, 154000, 317000, 264132,
#        283463, 243000, 109000, 305000,  93500, 176000, 118858, 134000,
#        109008,  93500, 611657, 173000, 348000, 341000, 141000, 124900,
#        118000,  67000, 113000,  91300, 149500, 133000, 266000, 190000,
#        155900, 155835, 153500, 152000, 124500, 301000, 136500, 169990,
#        205000, 183900, 204900, 260000, 163500, 224900, 244000, 132000,
# ...

# %%
sum(abs(y_pred - y_test))/len(y_pred)
# Out:
# array([0.73469443, 1.5775955 , 0.83708154, 0.74103802, 1.56016747,
#        1.57658226, 0.88890211, 0.73781956, 1.58516703, 0.77853893,
#        0.72054878, 0.94402179, 1.09879425, 0.98952798, 0.80829499,
#        0.89415221, 0.93675226, 0.83290841, 0.81891292, 0.95979674,
#        0.72870772, 1.03330297, 0.75943462, 0.96111556, 0.91963676,
#        0.73429569, 0.8996851 , 1.06272497, 0.78664678, 0.89035088,
#        0.9049974 , 1.22091598, 0.83396816, 1.16861196, 1.39418875,
#        0.72795492, 0.71958813, 1.01209317, 1.69871519, 1.20699004,
#        0.72336874, 1.06427186, 0.88922377, 1.66848565, 0.77618752,
#        0.72081054, 0.93204591, 0.8850045 , 2.20710684, 0.75235552,
#        0.93711969, 0.79635496, 0.8951623 , 1.67646215, 0.7193644 ,
#        1.09352608, 0.91163893, 0.73289315, 0.72512847, 1.21544402,
#        1.61999221, 0.77310953, 1.65245112, 1.32043338, 1.4568825 ,
#        0.85463617, 1.00082304, 1.65555489, 0.96875605, 0.73947179,
# ...

# %% [markdown]
# # 检验测试集数据

# %%
import pandas as pd 
from sklearn.ensemble import RandomForestRegressor
# 之前训练的模型
rfr = clf

# %%
test_data = pd.read_csv('../data/test.csv')
test_data[cols].isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# GarageCars      1
# TotalBsmtSF     1
# FullBath        0
# TotRmsAbvGrd    0
# YearBuilt       0
# dtype: int64

# %%
# 因为数据中存在缺失值，所以不能直接predict，而且缺失值较少，所以我直接在excel文件中将缺失值改为了该列的均值。所以需要先算出平均值。
test_data['GarageCars'].describe()
# Out:
# count    1458.000000
# mean        1.766118
# std         0.775945
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: GarageCars, dtype: float64

# %%
test_data['TotalBsmtSF'].describe()
# Out:
# count    1458.000000
# mean     1046.117970
# std       442.898624
# min         0.000000
# 25%       784.000000
# 50%       988.000000
# 75%      1305.000000
# max      5095.000000
# Name: TotalBsmtSF, dtype: float64

# %%
# 将均值放入空缺值里面
cols2 = ['OverallQual','GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt']
cars = data_test['GarageCars'].fillna(1.766118)
bsmt = data_test['TotalBsmtSF'].fillna(1046.117970)
data_test_x = pd.concat( [data_test[cols2], cars, bsmt] ,axis=1)
data_test_x.isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# FullBath        0
# TotRmsAbvGrd    0
# YearBuilt       0
# GarageCars      0
# TotalBsmtSF     0
# dtype: int64

# %%
x = data_test_x.values
y_td_pre = rfr.predict(x)
print(y_td_pre)
print(y_td_pre.shape)
print(x.shape)
# Out:
# [ 92912.03   105479.18   135270.025  ...  99418.575   93407.78
#  173761.5975]
# (1459,)
# (1459, 7)

# %%
data_test_x
# Out:
#       OverallQual  GrLivArea  FullBath  TotRmsAbvGrd  YearBuilt  GarageCars  \
# 0               5        896         1             5       1961         1.0
# 1               6       1329         1             6       1958         1.0
# 2               5       1629         2             6       1997         2.0
# 3               6       1604         2             7       1998         2.0
# 4               8       1280         2             5       1992         2.0
# 5               6       1655         2             7       1993         2.0
# 6               6       1187         2             6       1992         2.0
# 7               6       1465         2             7       1998         2.0
# 8               7       1341         1             5       1990         2.0
# 9               4        882         1             4       1970         2.0
# 10              7       1337         2             5       1999         2.0
# ...

# %%
predictions = pd.DataFrame(y_td_pre,columns=['SalePrice'])
result = pd.concat([test_data.Id,predictions],axis=1)
result.columns
# Out:
# Index(['Id', 'SalePrice'], dtype='object')

# %%
result.to_csv('../data/predictions.csv',index=False)
